# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplcursors

# %%
#Phase 1
#Load the dataset using Pandas.
data=pd.read_csv("C:\\Users\\saika\\Downloads\\GDP_DataSet.csv",delimiter=',',skiprows=4,header=0)
#Display the first few rows to understand its structure.
data.head(5)
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.121696e+10  2.230747e+10  2.370247e+10  2.577938e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.188413e+10  1.268566e+10  1.360683e+10  1.443998e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2015          2016          2017  \
# ...

# %%
#Check for missing values, data types, and column names.
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# Unnamed: 68       float64
# Length: 69, dtype: object

# %%
data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              128
#                  ...
# 2020                9
# 2021               10
# 2022               16
# 2023               33
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
#Displaying data null values in the percentage 
data.isnull().sum()/len(data)*100
# Out:
# Country Name        0.000000
# Country Code        0.000000
# Indicator Name      0.000000
# Indicator Code      0.000000
# 1960               48.120301
#                      ...
# 2020                3.383459
# 2021                3.759398
# 2022                6.015038
# 2023               12.406015
# Unnamed: 68       100.000000
# Length: 69, dtype: float64

# %%
#column name
data.columns.to_list()
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  'Unnamed: 68']

# %%
column_fill=['1960','1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980']
for columns in column_fill:
    data[columns]=data[columns].fillna(data[columns].min())

# %%
column_fillup=['1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023']
for col in column_fillup:
    data[col]=data[col].fillna(data[col].min())

# %%
data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                0
#                  ...
# 2020                0
# 2021                0
# 2022                0
# 2023                0
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
# Identify columns with "Unnamed" in their names
unnamed_columns = [col for col in data.columns if "Unnamed" in col]
print("Unnamed Columns:", unnamed_columns)
# Out:
# Unnamed Columns: ['Unnamed: 68']

# %%
# Drop columns with "Unnamed" in their names
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#All the dtypes are based on float
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# Length: 68, dtype: object

# %% [markdown]
# #Plot GDP trends over time for major countries (e.g., line plots for a few selected countries).

# %%
countries_to_plot=['China','India','United States','Australia']
filter_data=data[data['Country Name'].isin(countries_to_plot)]

filter_data.set_index('Country Name',inplace=True)
filter_data = filter_data.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'])
filter_data.head(5)
# Out:
#                        1960          1961          1962          1963  \
# Country Name
# Australia      1.860656e+10  1.968288e+10  1.992256e+10  2.153984e+10
# China          5.971625e+10  5.005669e+10  4.720919e+10  5.070661e+10
# India          3.702988e+10  3.923244e+10  4.216148e+10  4.842192e+10
# United States  5.419886e+11  5.619403e+11  6.036394e+11  6.370586e+11
#
#                        1964          1965          1966          1967  \
# Country Name
# Australia      2.380112e+10  2.597616e+10  2.730784e+10  3.044272e+10
# China          5.970813e+10  7.043601e+10  7.672001e+10  7.288136e+10
# India          5.648029e+10  5.955611e+10  4.558123e+10  5.013494e+10
# United States  6.841446e+11  7.419049e+11  8.130328e+11  8.596200e+11
#
#                        1968          1969  ...          2014          2015  \
# Country Name                               ...
# Australia      3.271409e+10  3.668337e+10  ...  1.468598e+12  1.351769e+12
# ...

# %%
#Transpose the Data
filter_data=filter_data.T
filter_data.head(5)
# Out:
# Country Name     Australia         China         India  United States
# 1960          1.860656e+10  5.971625e+10  3.702988e+10   5.419886e+11
# 1961          1.968288e+10  5.005669e+10  3.923244e+10   5.619403e+11
# 1962          1.992256e+10  4.720919e+10  4.216148e+10   6.036394e+11
# 1963          2.153984e+10  5.070661e+10  4.842192e+10   6.370586e+11
# 1964          2.380112e+10  5.970813e+10  5.648029e+10   6.841446e+11

# %%
filter_data.plot(figsize=(12,6))
plt.title=("GDP Trends Over time for India,USA,China")
plt.xlabel("Year")
plt.ylabel("GDP (current US$)")
plt.legend(title="Country")
cursor=mplcursors.cursor(hover=True)
@cursor.connect("add")
def on_add(sel):
    year = sel.target[0]  # Get the x-coordinate (year)
    gdp_value = sel.target[1]  # Get the y-coordinate (GDP value)
    sel.annotation.set(text=f"Year: {int(year)}\nGDP: ${gdp_value:,.0f}")
    sel.annotation.get_bbox_patch().set(fc="white", alpha=0.8)  # Set background for better visibility

plt.show()

# %% [markdown]
# - Examine any anomalies, trends, or seasonal patterns.
# z-score and interquartile Range(IQR)
#
# i
